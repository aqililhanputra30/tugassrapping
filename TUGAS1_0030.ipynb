# %% [markdown]
# <a href="https://colab.research.google.com/github/aqililhanputra30/tugassrapping/blob/main/TUGAS1_0030.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-search-results
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_maps",
  "q": "mie ayam",
  "ll": "@-6.9978354,110.4072681,15z",
  "type": "search",
  "api_key": "7dfc31a930d42a121191611e0a3617a7a8ada1e3fdaee846bce20f8e64576826"
}

search = GoogleSearch(params)
results = search.get_dict()
local_results = results["local_results"]
# Out:
# https://serpapi.com/search

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
local_results
# Out:
# [{'position': 1,
#   'title': 'Mie Ayam Pak Djo Sari Roso',
#   'place_id': 'ChIJFZIPHlCLcC4RQauHiUeZFV8',
#   'data_id': '0x2e708b501e0f9215:0x5f1599478987ab41',
#   'data_cid': '6851550940643175233',
#   'reviews_link': 'https://serpapi.com/search.json?data_id=0x2e708b501e0f9215%3A0x5f1599478987ab41&engine=google_maps_reviews&hl=en',
#   'photos_link': 'https://serpapi.com/search.json?data_id=0x2e708b501e0f9215%3A0x5f1599478987ab41&engine=google_maps_photos&hl=en',
#   'gps_coordinates': {'latitude': -6.9849083, 'longitude': 110.4143421},
#   'place_id_search': 'https://serpapi.com/search.json?data=%214m5%213m4%211s0x2e708b501e0f9215%3A0x5f1599478987ab41%218m2%213d-6.9849083%214d110.4143421&engine=google_maps&google_domain=google.com&hl=en&type=place',
#   'rating': 4.5,
#   'reviews': 265,
#   'unclaimed_listing': True,
#   'type': 'Noodle shop',
#   'address': '2C87+2PP, Jl. Pekunden Barat, Miroto, Semarang Tengah, Semarang City, Central Java 50134, Indonesia',
# ...

# %%
#1
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b501e0f9215:0x5f1599478987ab41",
  "api_key": "7dfc31a930d42a121191611e0a3617a7a8ada1e3fdaee846bce20f8e64576826"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"]

# %%
results
# Out:
# {'search_metadata': {'id': '6342e748e13508f1c25a5b31',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/0b8e660a3c8c66bf/6342e748e13508f1c25a5b31.json',
#   'created_at': '2022-10-09 15:22:48 UTC',
#   'processed_at': '2022-10-09 15:22:48 UTC',
#   'google_maps_url': 'https://www.google.com/maps/search/@-6.9978354,110.4072681,15z/mie+ayam?hl=en',
#   'raw_html_file': 'https://serpapi.com/searches/f341e357058c263b/6342e748e13508f1c25a5b31.html',
#   'total_time_taken': 1.24},
#  'search_parameters': {'engine': 'google_maps',
#   'type': 'search',
#   'q': 'mie ayam',
#   'll': '@-6.9978354,110.4072681,15z',
#   'google_domain': 'google.com',
#   'hl': 'en'},
#  'search_information': {'local_results_state': 'Results for exact spelling',
#   'query_displayed': 'mie ayam'},
#  'local_results': [{'position': 1,
#    'title': 'Mie Ayam Pak Djo Sari Roso',
#    'place_id': 'ChIJFZIPHlCLcC4RQauHiUeZFV8',
#    'data_id': '0x2e708b501e0f9215:0x5f1599478987ab41',
# ...

# %%
for i in range(10):
  rating = results ["reviews"][i]["rating"]
  print(rating)
  reviews = results ["reviews"][i]["snippet"]
  print(reviews)

# %%
#2
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b6e0f3c7a6b:0xc2bf258c78bbe9e",
  "api_key": "7dfc31a930d42a121191611e0a3617a7a8ada1e3fdaee846bce20f8e64576826"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"]

# %%
results

# %%
for i in range(10):
  rating = results ["reviews"][i]["rating"]
  print(rating)
  reviews = results ["reviews"][i]["snippet"]
  print(reviews)

# %%
#3
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b6053d0c753:0xe6c527d04999ccbe",
  "api_key": "7dfc31a930d42a121191611e0a3617a7a8ada1e3fdaee846bce20f8e64576826"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"]

# %%
results

# %%
for i in range(10):
  rating = results ["reviews"][i]["rating"]
  print(rating)
  reviews = results ["reviews"][i]["snippet"]
  print(reviews)

# %%
#4
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b5c015ba10f:0x8bb90636eecfdb18",
  "api_key": "7dfc31a930d42a121191611e0a3617a7a8ada1e3fdaee846bce20f8e64576826"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"]

# %%
results

# %%
for i in range(10):
  rating = results ["reviews"][i]["rating"]
  print(rating)
  reviews = results ["reviews"][i]["snippet"]
  print(reviews)

# %%
#5
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b6f901bc243:0xc81c224162c75925",
  "api_key": "7dfc31a930d42a121191611e0a3617a7a8ada1e3fdaee846bce20f8e64576826"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"]

# %%
results

# %%
for i in range(10):
  rating = results ["reviews"][i]["rating"]
  print(rating)
  reviews = results ["reviews"][i]["snippet"]
  print(reviews)

# %%
#5
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b6f901bc243:0xc81c224162c75925",
  "api_key": "7dfc31a930d42a121191611e0a3617a7a8ada1e3fdaee846bce20f8e64576826"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"]

# %%
results
# Out:
# {'search_metadata': {'id': '6342e748e13508f1c25a5b31',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/0b8e660a3c8c66bf/6342e748e13508f1c25a5b31.json',
#   'created_at': '2022-10-09 15:22:48 UTC',
#   'processed_at': '2022-10-09 15:22:48 UTC',
#   'google_maps_url': 'https://www.google.com/maps/search/@-6.9978354,110.4072681,15z/mie+ayam?hl=en',
#   'raw_html_file': 'https://serpapi.com/searches/f341e357058c263b/6342e748e13508f1c25a5b31.html',
#   'total_time_taken': 1.24},
#  'search_parameters': {'engine': 'google_maps',
#   'type': 'search',
#   'q': 'mie ayam',
#   'll': '@-6.9978354,110.4072681,15z',
#   'google_domain': 'google.com',
#   'hl': 'en'},
#  'search_information': {'local_results_state': 'Results for exact spelling',
#   'query_displayed': 'mie ayam'},
#  'local_results': [{'position': 1,
#    'title': 'Mie Ayam Pak Djo Sari Roso',
#    'place_id': 'ChIJFZIPHlCLcC4RQauHiUeZFV8',
#    'data_id': '0x2e708b501e0f9215:0x5f1599478987ab41',
# ...

# %%
for i in range(10):
  rating = results ["reviews"][i]["rating"]
  print(rating)
  reviews = results ["reviews"][i]["snippet"]
  print(reviews)

# %%
#6
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708ba124ed54f9:0x41dc391f56566aa9",
  "api_key": "7dfc31a930d42a121191611e0a3617a7a8ada1e3fdaee846bce20f8e64576826"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"]

# %%
results

# %%
for i in range(10):
  rating = results ["reviews"][i]["rating"]
  print(rating)
  reviews = results ["reviews"][i]["snippet"]
  print(reviews)

# %%
#7
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b812ff25143:0x1e5d1fd8d664ea1f",
  "api_key": "7dfc31a930d42a121191611e0a3617a7a8ada1e3fdaee846bce20f8e64576826"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"]

# %%
results

# %%
for i in range(10):
  rating = results ["reviews"][i]["rating"]
  print(rating)
  reviews = results ["reviews"][i]["snippet"]
  print(reviews)

# %%
#8
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b60137ed1b9:0xccd3466439f25f25",
  "api_key": "7dfc31a930d42a121191611e0a3617a7a8ada1e3fdaee846bce20f8e64576826"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"]

# %%
results

# %%
for i in range(10):
  rating = results ["reviews"][i]["rating"]
  print(rating)
  reviews = results ["reviews"][i]["snippet"]
  print(reviews)

# %%
#9
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b59824042b3:0x7ac384a28a639c02",
  "api_key": "7dfc31a930d42a121191611e0a3617a7a8ada1e3fdaee846bce20f8e64576826"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"]

# %%
results

# %%
for i in range(10):
  rating = results ["reviews"][i]["rating"]
  print(rating)
  reviews = results ["reviews"][i]["snippet"]
  print(reviews)

# %%
#10
from serpapi import GoogleSearch

params = {
  "engine": "google_maps_reviews",
  "data_id": "0x2e708b59824042b3:0x7ac384a28a639c02",
  "api_key": "7dfc31a930d42a121191611e0a3617a7a8ada1e3fdaee846bce20f8e64576826"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results["reviews"]

# %%
results

# %%
for i in range(10):
  rating = results ["reviews"][i]["rating"]
  print(rating)
  reviews = results ["reviews"][i]["snippet"]
  print(reviews)

# %%
## case folding ##

# %%
kalimat = "4.0 mie ayam murah porsi istimewa cuma 11k.tapi mie nya agak tercium bau sangit,mungkin air yg buat merebus mienya sdah hmpir habis dan perlu di refil kmbali"
lower_case = kalimat.lower()
print(lower_case)
# Out:
# 4.0 mie ayam murah porsi istimewa cuma 11k.tapi mie nya agak tercium bau sangit,mungkin air yg buat merebus mienya sdah hmpir habis dan perlu di refil kmbali

# %%
## tokenizing ##

# %%
import nltk
nltk.download('book')
#or
nltk.download('tests')
#or
nltk.download('all-corpora')# not recommended as it download huge amount of data.
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# ...

# %%
from nltk.tokenize import sent_tokenize, word_tokenize 
kalimat = "Pertama kali nyoba mie ayam disini, yang katanya enak dan ternyata beneran enak."
kalimat= kalimat+"Mie ayam yang lazat, Penggemar mie ayam harus nyoba.."
tokens = word_tokenize(kalimat)
print(tokens)
# Out:
# ['Pertama', 'kali', 'nyoba', 'mie', 'ayam', 'disini', ',', 'yang', 'katanya', 'enak', 'dan', 'ternyata', 'beneran', 'enak.Mie', 'ayam', 'yang', 'lazat', ',', 'Penggemar', 'mie', 'ayam', 'harus', 'nyoba', '..']

# %%
## stopword removal ##

# %%
pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 209 kB 14.8 MB/s
# ...

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()
print(stopwords)
# Out:
# ['yang', 'untuk', 'pada', 'ke', 'para', 'namun', 'menurut', 'antara', 'dia', 'dua', 'ia', 'seperti', 'jika', 'jika', 'sehingga', 'kembali', 'dan', 'tidak', 'ini', 'karena', 'kepada', 'oleh', 'saat', 'harus', 'sementara', 'setelah', 'belum', 'kami', 'sekitar', 'bagi', 'serta', 'di', 'dari', 'telah', 'sebagai', 'masih', 'hal', 'ketika', 'adalah', 'itu', 'dalam', 'bisa', 'bahwa', 'atau', 'hanya', 'kita', 'dengan', 'akan', 'juga', 'ada', 'mereka', 'sudah', 'saya', 'terhadap', 'secara', 'agar', 'lain', 'anda', 'begitu', 'mengapa', 'kenapa', 'yaitu', 'yakni', 'daripada', 'itulah', 'lagi', 'maka', 'tentang', 'demi', 'dimana', 'kemana', 'pula', 'sambil', 'sebelum', 'sesudah', 'supaya', 'guna', 'kah', 'pun', 'sampai', 'sedangkan', 'selagi', 'sementara', 'tetapi', 'apakah', 'kecuali', 'sebab', 'selain', 'seolah', 'seraya', 'seterusnya', 'tanpa', 'agak', 'boleh', 'dapat', 'dsb', 'dst', 'dll', 'dahulu', 'dulunya', 'anu', 'demikian', 'tapi', 'ingin', 'juga', 'nggak', 'mari', 'nanti', 'melainkan',
# ...

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()
# Kalimat
kalimat = "Mie ayam dengan kuah gurih cenderung asin  Mienya lembut, baksonya empuk dan berasa daging sapinya."
stop = stopword.remove(kalimat)
print(stop)
# Out:
# Mie ayam kuah gurih cenderung asin  Mienya lembut, baksonya empuk berasa daging sapinya.

# %%
## stemming ##

# %%
pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()# stemming process
sentence = "Pangsit gorengnya renyah dan gurih. Enak.Tempat makan tidak cukup luas. "
output   = stemmer.stem(sentence)
print(output)
# Out:
# pangsit goreng renyah dan gurih enak tempat makan tidak cukup luas
